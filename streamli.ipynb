# %%
# !pip install streamlit --quiet
# !pip install pyngrok==4.1.1 --quiet
# !pip install streamlit-drawable-canvas --quiet
# Out:
#      |████████████████████████████████| 8.2MB 3.9MB/s
#      |████████████████████████████████| 4.2MB 40.8MB/s
#      |████████████████████████████████| 112kB 58.5MB/s
#      |████████████████████████████████| 174kB 50.4MB/s
#      |████████████████████████████████| 92kB 8.3MB/s
#      |████████████████████████████████| 81kB 9.9MB/s
#      |████████████████████████████████| 122kB 56.9MB/s
#      |████████████████████████████████| 71kB 8.5MB/s
#   Building wheel for blinker (setup.py) ... done
# ERROR: google-colab 1.0.0 has requirement ipykernel~=4.10, but you'll have ipykernel 5.5.5 which is incompatible.
#   Building wheel for pyngrok (setup.py) ... done
#      |████████████████████████████████| 1.3MB 4.0MB/s

# %%
from pyngrok import ngrok

# %%
# %%writefile app1.py
import streamlit as pt
from streamlit_drawable_canvas import st_canvas
from tensorflow import keras
model_new = keras.models.load_model('fashion_mnist.hdf5')
import numpy as np
op = model_new.predict(a.reshape(1,28,28))
label = "T-shirt/top Trouser Pullover Dress	Coat Sandal	Shirt	Sneaker	Bag	Ankle-boot"
label = label.split()
label
z = label[np.argmax(op)]
st.title(z)
# Out:
# Writing app1.py

# %%
# !nohup streamlit run app.py &
url = ngrok.connect(port='8501')
url
# Out:
# nohup: appending output to 'nohup.out'
# 'http://59c85c81e01a.ngrok.io'
